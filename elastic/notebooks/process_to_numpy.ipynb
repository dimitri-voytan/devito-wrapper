# %%
import numpy as np
import matplotlib.pyplot as plt

shape = (500, 174)
vp = np.fromfile('../data/mar_zz_vp.dir', dtype='float32').reshape(shape)
vs = np.fromfile('../data/mar_zz_vs.dir', dtype='float32').reshape(shape)
rho = np.fromfile('../data/mar_zz_rho.dir', dtype='float32').reshape(shape)

# %%
shot = np.load(r'../output/Feb-15-2022/00:02:19/shot.npy', allow_pickle=True).item()
v1 = shot['v_2']

fig, axs = plt.subplots(figsize=(10,10))
plt.imshow(v1, cmap='Greys', vmin=-1e-8, vmax=1e-8)

# %%
print(np.min(v1))
# Out:
# -2.060562899976852e-08

# %%
import numpy as np
import matplotlib.pyplot as plt

shape = (500, 174)

# %%
shot = np.load(r'../output/Feb-15-2022/12:49:55/shot.npy', allow_pickle=True).item()
v1 = shot['v_2']

fig, axs = plt.subplots(figsize=(10,10))
plt.imshow(v1[::4, :], cmap='Greys', vmin=-0.0025, vmax=0.0025)
